# %%
# %tensorflow_version 2.x

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()


x_train = x_train / x_train.max()
x_test = x_test / x_test.max()


y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
f1 =Conv2D(27, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu')
f2 = MaxPool2D()
f30 = Conv2D(243, (3, 3), padding='same', activation='selu')
f40 = MaxPool2D()
f31 = Conv2D(256, (3, 3), padding='same', activation='selu')
f41 = MaxPool2D()
f5 = Conv2D(729, (3, 3), padding='same', activation='elu')
f6 = GlobalAveragePooling2D()
f7 = Flatten()
f8 = Dense(units=81, activation='elu')
f9 = Dense(units=10, activation='softmax')

# %%
x = Input(shape=(32,32,3))

# %%
h1=f1(x)
h2 = f2(h1)
h30 = f30(h2)
h31 = f31(h2)
h40 = f40(h30)
h41 = f41(h31)

# %%
from tensorflow.keras.layers import concatenate, add

# %%
u = concatenate([h40,h41])
h5 = f5(u)
h6 = f6(h5)
h7 = f7(h6)
h8 = f8(h7)
y = f9(h8)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 32, 32, 27)        756
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 27)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 243)       59292
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 243)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 729)         1595052
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 729)               0
# _________________________________________________________________
# dense (Dense)                (None, 81)                59130
# ...

# %%
x_train[1].shape
# Out:
# (32, 32, 3)

# %%
model_ouo = Model(x,y)

# %%
model_ouo.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 27)   756         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 27)   0           conv2d_7[1][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 243)  59292       max_pooling2d_5[1][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  62464       max_pooling2d_5[1][0]
# ...

# %%
model_ouo.input_shape
# Out:
# (None, 32, 32, 3)

# %%
model_ouo.output_shape
# Out:
# (None, 10)

# %%
model.compile(loss='mse', 
              optimizer=Adam(), 
              metrics=['accuracy'])

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive
# %cd "colab"
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/colab

# %%
model.fit(x_train, y_train, batch_size=1024, epochs=10)
# Out:
# Epoch 1/10
# 49/49 [==============================] - 14s 288ms/step - loss: 0.0298 - accuracy: 0.7917
# Epoch 2/10
# 49/49 [==============================] - 12s 236ms/step - loss: 0.0284 - accuracy: 0.8028
# Epoch 3/10
# 49/49 [==============================] - 12s 236ms/step - loss: 0.0279 - accuracy: 0.8085
# Epoch 4/10
# 49/49 [==============================] - 12s 236ms/step - loss: 0.0275 - accuracy: 0.8113
# Epoch 5/10
# 49/49 [==============================] - 12s 235ms/step - loss: 0.0274 - accuracy: 0.8124
# Epoch 6/10
# 49/49 [==============================] - 12s 236ms/step - loss: 0.0270 - accuracy: 0.8157
# Epoch 7/10
# 49/49 [==============================] - 12s 236ms/step - loss: 0.0263 - accuracy: 0.8205
# Epoch 8/10
# 49/49 [==============================] - 12s 237ms/step - loss: 0.0266 - accuracy: 0.8165
# Epoch 9/10
# 49/49 [==============================] - 12s 237ms/step - loss: 0.0262 - accuracy: 0.8219
# Epoch 10/10
# ...

# %%
mode1.evaluate()

# %%
model7 = Sequential()

# First convolutional block
model7.add(Conv2D(27, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu'))
model7.add(MaxPool2D())

# Second convolutional block
model7.add(Conv2D(243, (3, 3), padding='same', activation='relu'))
model7.add(MaxPool2D())

# Third convolutional block
model7.add(Conv2D(729, (3, 3), padding='same', activation='elu'))
model7.add(GlobalAveragePooling2D())

# Fully-connected layers as a classfier
model7.add(Dense(units=81, activation='selu'))

# Ouput layer: # of neurons = # of classes with softmax activation
model7.add(Dense(units=10, activation='softmax'))
model7.compile(loss='mse', 
              optimizer=Adam(), 
              metrics=['accuracy'])

# %%
model7.fit(x_train, y_train, batch_size=128, epochs=10)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0503 - accuracy: 0.6261
# Epoch 2/10
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0474 - accuracy: 0.6496
# Epoch 3/10
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0462 - accuracy: 0.6591
# Epoch 4/10
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0437 - accuracy: 0.6813
# Epoch 5/10
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0430 - accuracy: 0.6877
# Epoch 6/10
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0420 - accuracy: 0.6964
# Epoch 7/10
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0407 - accuracy: 0.7051
# Epoch 8/10
# 391/391 [==============================] - 15s 38ms/step - loss: 0.0400 - accuracy: 0.7099
# Epoch 9/10
# 391/391 [==============================] - 15s 37ms/step - loss: 0.0386 - accuracy: 0.7225
# Epoch 10/10
# ...

# %%
model.save("fin02.h5")
